# %% [markdown]
# # Proyecto 2
#
# **Tema:** Predicción de enfermedades Cardíacas
#
#
# |     Nombres      |      Apellidos       |     Login     |  Codigo   |
# | :--------------: | :------------------: | :-----------: | :-------: |
# |     Santiago     | Gonzalez Montealegre | s.gonzalez35  | 202012274 |
# | Juliana Carolina |  Cardenas Barragan   | jc.cardenasb1 | 202011683 |

# %% [markdown]
# ## Modelo Original

# %% [markdown]
# ## Librerías Requeridas

# %%
from pgmpy.readwrite import BIFReader

# %% [markdown]
# ## Leer Modelo

# %%
reader = BIFReader('../../../Data/Models/Original.bif')
model = reader.get_model()
model.check_model()
# Out:
# True

# %%
for i in model.nodes():
    print(i)
    print(model.get_cpds(i))
# Out:
# age
# +--------+----------+
# | age(1) | 0.247525 |
# +--------+----------+
# | age(2) | 0.250825 |
# +--------+----------+
# | age(3) | 0.240924 |
# +--------+----------+
# | age(4) | 0.260726 |
# +--------+----------+
# ca
# +-------+----------------------+-----+---------------------+
# | age   | age(1)               | ... | age(4)              |
# +-------+----------------------+-----+---------------------+
# | ca(0) | 0.88                 | ... | 0.3924050632911392  |
# +-------+----------------------+-----+---------------------+
# | ca(1) | 0.08                 | ... | 0.25316455696202533 |
# +-------+----------------------+-----+---------------------+
# | ca(2) | 0.02666666666666667  | ... | 0.21518987341772153 |
# +-------+----------------------+-----+---------------------+
# | ca(3) | 0.013333333333333334 | ... | 0.13924050632911392 |
# +-------+----------------------+-----+---------------------+
# cp
# +----------+---------------------+-----+----------------------+
# | exang    | exang(0)            | ... | exang(1)             |
# +----------+---------------------+-----+----------------------+
# | heartdis | heartdis(0)         | ... | heartdis(1)          |
# +----------+---------------------+-----+----------------------+
# | cp(1)    | 0.09219858156028368 | ... | 0.013157894736842105 |
# +----------+---------------------+-----+----------------------+
# | cp(2)    | 0.2695035460992908  | ... | 0.013157894736842105 |
# +----------+---------------------+-----+----------------------+
# | cp(3)    | 0.4326241134751773  | ... | 0.05263157894736842  |
# +----------+---------------------+-----+----------------------+
# | cp(4)    | 0.20567375886524822 | ... | 0.9210526315789473   |
# +----------+---------------------+-----+----------------------+
# exang
# +----------+---------------------+--------------------+---------------------+
# | thal     | thal(3)             | thal(6)            | thal(7)             |
# +----------+---------------------+--------------------+---------------------+
# | exang(0) | 0.8095238095238095  | 0.5555555555555556 | 0.49572649572649574 |
# +----------+---------------------+--------------------+---------------------+
# | exang(1) | 0.19047619047619047 | 0.4444444444444444 | 0.5042735042735043  |
# +----------+---------------------+--------------------+---------------------+
# heartdis
# +-------------+---------------------+-----+----------+----------+----------+
# | ca          | ca(0)               | ... | ca(3)    | ca(3)    | ca(3)    |
# +-------------+---------------------+-----+----------+----------+----------+
# | sex         | sex(0)              | ... | sex(1)   | sex(1)   | sex(1)   |
# +-------------+---------------------+-----+----------+----------+----------+
# | slope       | slope(1)            | ... | slope(3) | slope(3) | slope(3) |
# +-------------+---------------------+-----+----------+----------+----------+
# | thal        | thal(3)             | ... | thal(3)  | thal(6)  | thal(7)  |
# +-------------+---------------------+-----+----------+----------+----------+
# | heartdis(0) | 0.9354838709677419  | ... | 0.5      | 0.0      | 0.5      |
# +-------------+---------------------+-----+----------+----------+----------+
# | heartdis(1) | 0.06451612903225806 | ... | 0.5      | 1.0      | 0.5      |
# +-------------+---------------------+-----+----------+----------+----------+
# oldpeak
# +------------+-------------+-----+---------------------+
# | exang      | exang(0)    | ... | exang(1)            |
# +------------+-------------+-----+---------------------+
# | heartdis   | heartdis(0) | ... | heartdis(1)         |
# +------------+-------------+-----+---------------------+
# | slope      | slope(1)    | ... | slope(3)            |
# +------------+-------------+-----+---------------------+
# | thal       | thal(3)     | ... | thal(7)             |
# +------------+-------------+-----+---------------------+
# | oldpeak(1) | 0.7         | ... | 0.0                 |
# +------------+-------------+-----+---------------------+
# | oldpeak(2) | 0.15        | ... | 0.0                 |
# +------------+-------------+-----+---------------------+
# | oldpeak(3) | 0.075       | ... | 0.0                 |
# +------------+-------------+-----+---------------------+
# | oldpeak(4) | 0.075       | ... | 0.16666666666666666 |
# +------------+-------------+-----+---------------------+
# | oldpeak(5) | 0.0         | ... | 0.8333333333333334  |
# +------------+-------------+-----+---------------------+
# sex
# +--------+----------+
# | sex(0) | 0.320132 |
# +--------+----------+
# | sex(1) | 0.679868 |
# +--------+----------+
# slope
# +----------+-----------+
# | slope(1) | 0.468647  |
# +----------+-----------+
# | slope(2) | 0.462046  |
# +----------+-----------+
# | slope(3) | 0.0693069 |
# +----------+-----------+
# thal
# +---------+----------------------+---------------------+
# | sex     | sex(0)               | sex(1)              |
# +---------+----------------------+---------------------+
# | thal(3) | 0.8350515463917526   | 0.4223300970873786  |
# +---------+----------------------+---------------------+
# | thal(6) | 0.010309278350515464 | 0.0825242718446602  |
# +---------+----------------------+---------------------+
# | thal(7) | 0.15463917525773196  | 0.49514563106796117 |
# +---------+----------------------+---------------------+
# thalach
# +------------+----------+-----+---------------------+----------+
# | age        | age(1)   | ... | age(4)              | age(4)   |
# +------------+----------+-----+---------------------+----------+
# | exang      | exang(0) | ... | exang(1)            | exang(1) |
# +------------+----------+-----+---------------------+----------+
# | slope      | slope(1) | ... | slope(2)            | slope(3) |
# +------------+----------+-----+---------------------+----------+
# | thalach(1) | 0.1      | ... | 0.8333333333333334  | 1.0      |
# +------------+----------+-----+---------------------+----------+
# | thalach(2) | 0.9      | ... | 0.16666666666666666 | 0.0      |
# +------------+----------+-----+---------------------+----------+
# trestbps
# +-------------+--------+-----+---------------------+
# | age         | age(1) | ... | age(4)              |
# +-------------+--------+-----+---------------------+
# | trestbps(1) | 0.72   | ... | 0.43037974683544306 |
# +-------------+--------+-----+---------------------+
# | trestbps(2) | 0.28   | ... | 0.569620253164557   |
# +-------------+--------+-----+---------------------+
